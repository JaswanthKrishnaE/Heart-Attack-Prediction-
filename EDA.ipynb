# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('.\Spotify_Youtube.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...  \
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track
# 0                                 Feel Good Inc.  \
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type
# 0                                     Demon Days      album  \
# 1                                  Plastic Beach      album
# ...

# %%
df.shape
# Out:
# (20718, 28)

# %%
df.describe()
# Out:
#          Unnamed: 0  Danceability        Energy           Key      Loudness
# count  20718.000000  20716.000000  20716.000000  20716.000000  20716.000000  \
# mean   10358.500000      0.619777      0.635250      5.300348     -7.671680
# std     5980.915774      0.165272      0.214147      3.576449      4.632749
# min        0.000000      0.000000      0.000020      0.000000    -46.251000
# 25%     5179.250000      0.518000      0.507000      2.000000     -8.858000
# 50%    10358.500000      0.637000      0.666000      5.000000     -6.536000
# 75%    15537.750000      0.740250      0.798000      8.000000     -4.931000
# max    20717.000000      0.975000      1.000000     11.000000      0.920000
#
#         Speechiness  Acousticness  Instrumentalness      Liveness
# count  20716.000000  20716.000000      20716.000000  20716.000000  \
# mean       0.096456      0.291535          0.055962      0.193521
# std        0.111960      0.286299          0.193262      0.168531
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0          False
# Artist              False
# Url_spotify         False
# Track               False
# Album               False
# Album_type          False
# Uri                 False
# Danceability         True
# Energy               True
# Key                  True
# Loudness             True
# Speechiness          True
# Acousticness         True
# Instrumentalness     True
# Liveness             True
# Valence              True
# Tempo                True
# Duration_ms          True
# Url_youtube          True
# Title                True
# Channel              True
# Views                True
# Likes                True
# Comments             True
# Description          True
# Licensed             True
# official_video       True
# Stream               True
# dtype: bool

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20718 non-null  int64
#  1   Artist            20718 non-null  object
#  2   Url_spotify       20718 non-null  object
#  3   Track             20718 non-null  object
#  4   Album             20718 non-null  object
#  5   Album_type        20718 non-null  object
#  6   Uri               20718 non-null  object
#  7   Danceability      20716 non-null  float64
#  8   Energy            20716 non-null  float64
#  9   Key               20716 non-null  float64
#  10  Loudness          20716 non-null  float64
#  11  Speechiness       20716 non-null  float64
#  12  Acousticness      20716 non-null  float64
#  13  Instrumentalness  20716 non-null  float64
#  14  Liveness          20716 non-null  float64
#  15  Valence           20716 non-null  float64
# ...

# %%
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"Column '{col}' has {len(unique_vals)} unique values:")
    print(unique_vals)
# Out:
# Column 'Unnamed: 0' has 20718 unique values:
# [    0     1     2 ... 20715 20716 20717]
# Column 'Artist' has 2079 unique values:
# ['Gorillaz' 'Red Hot Chili Peppers' '50 Cent' ... 'LE SSERAFIM' 'ThxSoMch'
#  'SICK LEGEND']
# Column 'Url_spotify' has 2079 unique values:
# ['https://open.spotify.com/artist/3AA28KZvwAUcZuOKwyblJQ'
#  'https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5'
#  'https://open.spotify.com/artist/3q7HBObVc0L8jNeTe5Gofh' ...
#  'https://open.spotify.com/artist/4SpbR6yFEvexJuaBpgAU5p'
#  'https://open.spotify.com/artist/4MvZhE1iuzttcoyepkpfdF'
#  'https://open.spotify.com/artist/3EYY5FwDkHEYLw5V86SAtl']
# Column 'Track' has 17841 unique values:
# ['Feel Good Inc.' 'Rhinestone Eyes'
#  'New Gold (feat. Tame Impala and Bootie Brown)' ...
#  'OUTSIDE HARDSTYLE SPED UP' 'ONLY GIRL HARDSTYLE' 'MISS YOU HARDSTYLE']
# Column 'Album' has 11937 unique values:
# ['Demon Days' 'Plastic Beach'
#  'New Gold (feat. Tame Impala and Bootie Brown)' ...
# ...

# %%
df.dropna(inplace=True)
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (19170, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19170 entries, 0 to 20717
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        19170 non-null  int64
#  1   Artist            19170 non-null  object
#  2   Url_spotify       19170 non-null  object
#  3   Track             19170 non-null  object
#  4   Album             19170 non-null  object
#  5   Album_type        19170 non-null  object
#  6   Uri               19170 non-null  object
#  7   Danceability      19170 non-null  float64
#  8   Energy            19170 non-null  float64
#  9   Key               19170 non-null  float64
#  10  Loudness          19170 non-null  float64
#  11  Speechiness       19170 non-null  float64
#  12  Acousticness      19170 non-null  float64
#  13  Instrumentalness  19170 non-null  float64
#  14  Liveness          19170 non-null  float64
#  15  Valence           19170 non-null  float64
# ...

# %%
num_cols = df.select_dtypes(include=[np.number]).columns # get numerical columns
df[num_cols].hist(bins=20, figsize=(15,12))
plt.show()

# %%
df.Album_type
# Out:
# 0         album
# 1         album
# 2        single
# 3         album
# 4         album
#           ...
# 20713    single
# 20714    single
# 20715    single
# 20716    single
# 20717    single
# Name: Album_type, Length: 19170, dtype: object

# %%
Album_type=df.groupby("Album_type")[["Views"]].sum()
Album_type.sort_values(by ="Views", ascending=False)
# Out:
#                     Views
# Album_type
# album        1.410484e+12
# single       3.939238e+11
# compilation  5.887175e+10

# %%
Album_type.plot.barh(y='Views',color='green')
plt.title('Views Per Album Type')
plt.show()

# %%
streamers = df.groupby('Album_type')[['Stream']].sum()
streamers
# Out:
#                    Stream
# Album_type
# album        2.114051e+12
# compilation  5.951055e+10
# single       4.771631e+11

# %%
streamers.plot.pie(y = 'Stream')
plt.title('Streams Per Album Type')
plt.show()

# %%
holdi = df.sort_values(by = 'Stream', ascending = False)[['Track', 'Artist', 'Stream']].head(6)
plt.figure(figsize=(19,6))
sns.barplot(data = holdi, x= 'Track', y='Stream', palette = 'Greens_r')
plt.title("Top 5 Songs on Spotify")
plt.ylabel("Billions of Streams", color = 'lightgrey')
plt.xlabel("Song", color = 'lightgrey')
plt.show()

# %%
holdi = df.sort_values(by = 'Views', ascending = False)[['Track', 'Artist', 'Views']].head(7)
plt.figure(figsize=(19,6))
sns.barplot(data = holdi, x= 'Track', y='Views', palette = 'Reds_r')
plt.title("Top 5 Songs on Youtube")
plt.ylabel("Billions of Views", color = 'lightgrey')
plt.xlabel("Song", color = 'lightgrey')
plt.show()

# %%
Artists = df.groupby('Artist')[['Views']].sum()
Artists.sort_values(by = 'Views', ascending = False).head(5)
# Out:
#                      Views
# Artist
# Ed Sheeran    1.546021e+10
# CoComelon     1.460167e+10
# Katy Perry    1.312063e+10
# Charlie Puth  1.216759e+10
# Luis Fonsi    1.162811e+10

# %%
Artists.sort_values(by = 'Views', ascending = False).head(5).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Artist'>

# %%
Channel=df.groupby("Channel")[["Views"]].sum()
Channel.sort_values(by = 'Views',ascending=False).head(10)
# Out:
#                                    Views
# Channel
# T-Series                    4.779864e+10
# LuisFonsiVEVO               2.170252e+10
# CalvinHarrisVEVO            1.828114e+10
# Macklemore                  1.700341e+10
# Ed Sheeran                  1.691822e+10
# Hear This Music             1.508851e+10
# Cocomelon - Nursery Rhymes  1.460167e+10
# Bruno Mars                  1.301357e+10
# KatyPerryVEVO               1.247680e+10
# DJSnakeVEVO                 1.245510e+10

# %%
Channel.sort_values(by = 'Views',ascending=False).head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Channel'>

# %%
track = df.groupby('Track')[['Views']].sum()
track
# Out:
#                                    Views
# Track
# !ly (feat. Coez)              11828802.0
# #1 - Colby O'Donis Remix      50109737.0
# #3                            18316658.0
# #41                            4160936.0
# #Ysya2020 Vol. 5 - Silbando    1866183.0
# ...                                  ...
# 高嶺の花子さん                       73883526.0
# 그대라는 시                         3513557.0
# 눈,코,입 (Eyes, Nose, Lips)     237696728.0
# 러시안 룰렛 Russian Roulette      244786739.0
# 링가링가 (RINGA LINGA)           138130315.0
#
# [16547 rows x 1 columns]

# %%
track.sort_values(by='Views',ascending=False).head(10).unstack().plot(x = 'Views', y ='Track' ,kind = 'bar' )
# Out:
# <Axes: xlabel='None,Track'>

# %%
df['dur_min']=(df['Duration_ms']/1000)/60
df['dur_min'].head()
# Out:
# 0    3.710667
# 1    3.336217
# 2    3.585833
# 3    3.897783
# 4    5.682000
# Name: dur_min, dtype: float64

# %%
df.sort_values(by = 'dur_min',ascending=False).head(1)
# Out:
#        Unnamed: 0          Artist
# 10475       10475  Harshdeep Kaur  \
#
#                                              Url_spotify
# 10475  https://open.spotify.com/artist/3xU8YsNNkmWSPe...  \
#
#                                                    Track
# 10475  High Rated Gabru 52 Non Stop Hits(Remix By Man...  \
#
#                                    Album   Album_type
# 10475  High Rated Gabru 52 Non Stop Hits  compilation  \
#
#                                         Uri  Danceability  Energy  Key  ...
# 10475  spotify:track:2HyMuSCZJIxgnZBkuPT3TA         0.385   0.935  2.0  ...  \
#
#                                                    Title
# 10475  High Rated Gabru 52 Non Stop Hits (Remix By Ma...  \
#
#                       Channel    Views  Likes  Comments
# 10475  Ali Quli Mirza - Topic  34624.0  324.0       1.0  \
#
#                                              Description  Licensed
# 10475  Provided to YouTube by Super Cassettes Industr...      True  \
#
# ...

# %%
df.sort_values(by = 'dur_min',ascending=False).tail(1)['dur_min']
# Out:
# 11926    0.516417
# Name: dur_min, dtype: float64

# %%
sns.histplot(df['dur_min'].sort_values(ascending = True).head(19000), bins = 20, color = 'lightgrey')
# Out:
# <Axes: xlabel='dur_min', ylabel='Count'>

# %%
artists2 = df.groupby('Artist')[['Stream']].sum()
artists2.sort_values(by = 'Stream').head(10)
# Out:
#                            Stream
# Artist
# Sir Arthur Conan Doyle   103471.0
# Fünf Freunde             398843.0
# Bibi Blocksberg          566474.0
# Traditional             1010029.0
# Sherlock Holmes         1046010.0
# Teufelskicker           1115469.0
# Thomas Karallus         1119876.0
# TKKG                    1273118.0
# L.V.                    2241476.0
# Los Amables Del Norte   2288022.0

# %%
plt.figure(figsize=(19,6))
sns.lineplot(artists2.sort_values(by = 'Stream').head(10))
# Out:
# <Axes: xlabel='Artist'>

# %%
plt.figure(figsize=(19,6))
sns.histplot(x = df['Views'].sort_values(ascending = False).head(1000), bins = 20, color = 'lightcyan')
plt.title("View Distribution of Top 1000 Songs", loc = 'left', color = 'grey')
# Out:
# Text(0.0, 1.0, 'View Distribution of Top 1000 Songs')

# %%
(1 - len(df[df['Views'] < 1000000000]) / len(df)) * 100
# Out:
# 1.5492957746478853

# %%
df['like_percent'] = df['Likes']/ df['Views']
df['like_percent'] = df['like_percent'].apply(lambda x: round(x, 3))
df['like_percent']
# df2 = df[df['Views'] > 5000000]
# df2.sort_values(by = 'like_percent', ascending = False).head(10)[['Artist', 'Track', 'Views', 'like_percent']]
# Out:
# 0        0.009
# 1        0.015
# 2        0.033
# 3        0.008
# 4        0.010
#          ...
# 20713    0.016
# 20714    0.012
# 20715    0.009
# 20716    0.013
# 20717    0.016
# Name: like_percent, Length: 19170, dtype: float64

# %%
df.sort_values(by='like_percent',ascending=False).head(10).loc[:,['Track','Album_type','Artist']]
# Out:
#                                        Track Album_type      Artist
# 19968                                  Intro      album      j-hope
# 19969                            Safety Zone      album      j-hope
# 19967                                 Future      album      j-hope
# 19971                          Pandora's Box      album      j-hope
# 16297           My Universe - Galantis Remix     single    Galantis
# 15065                    Burn It (feat. MAX)      album         MAX
# 8105                  No.2 (with parkjiyoon)      album          RM
# 14564  Bad Decisions (with BTS & Snoop Dogg)     single         BTS
# 8104                     Hectic (with Colde)      album          RM
# 19160       TASTE (Lee Know, Hyunjin, Felix)      album  Stray Kids

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from scipy import stats

# %%
df.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...  \
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track
# 0                                 Feel Good Inc.  \
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type
# 0                                     Demon Days      album  \
# 1                                  Plastic Beach      album
# ...
